# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulArra/Machine-Learning/blob/main/ML_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dict1 = { "State" : ["Assam ", " Delhi", " Kerala"], "Geographic Area" :[782324,83479,32421],"densforest" : [3847,34,23]}
df1 = pd.DataFrame(dict1)
df1
# Out:
#      State  Geographic Area  densforest
# 0   Assam            782324        3847
# 1    Delhi            83479          34
# 2   Kerala            32421          23
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Geographic Area'].plot(kind='hist', bins=20, title='Geographic Area')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['densforest'].plot(kind='hist', bins=20, title='densforest')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>

# %%
df2 = pd.DataFrame(dict1,index=["A","B","C"])
df2
# Out:
#      State  Geographic Area  densforest
# A   Assam            782324        3847
# B    Delhi            83479          34
# C   Kerala            32421          23

# %%
s1= pd.Series([])
