# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulArra/Machine-Learning/blob/main/ML_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dict1 = {
    "2014" :[100.5,150.8,200.9,30000,40000],
    "2015":[12000,18000,22000,30000,45000],
    "2016":[20000,50000,70000,100000,125000],
    "2017":[50000,60000,70000,80000,90000]
}
indexes = ["Madhu","Kusum","Kinshuk","Ankit","Shruti"]
df = pd.DataFrame(dict1, index = indexes)
df
# Out:
#             2014   2015    2016   2017
# Madhu      100.5  12000   20000  50000
# Kusum      150.8  18000   50000  60000
# Kinshuk    200.9  22000   70000  70000
# Ankit    30000.0  30000  100000  80000
# Shruti   40000.0  45000  125000  90000

# %%
#row labels
print(df.index)
# Out:
# Index(['Madhu', 'Kusum', 'Kinshuk', 'Ankit', 'Shruti'], dtype='object')

# %%
#column labels
print(df.columns)
# Out:
# Index(['2014', '2015', '2016', '2017'], dtype='object')

# %%
# datatype fo each colummns
print(df.dtypes)
# Out:
# 2014    float64
# 2015      int64
# 2016      int64
# 2017      int64
# dtype: object

# %%
# dim , shape , size and values of df
print("dimension : ", df.ndim)
print("shapes : ",df.shape)
print("size : ",df.size)
print("Values : ",df.values)
# Out:
# dimension :  2
# shapes :  (5, 4)
# size :  20
# Values :  [[1.005e+02 1.200e+04 2.000e+04 5.000e+04]
#  [1.508e+02 1.800e+04 5.000e+04 6.000e+04]
#  [2.009e+02 2.200e+04 7.000e+04 7.000e+04]
#  [3.000e+04 3.000e+04 1.000e+05 8.000e+04]
#  [4.000e+04 4.500e+04 1.250e+05 9.000e+04]]

# %%
# last 2 rows and frst 2 rows
print(df.tail(2))
print(df.head(2))
# Out:
#            2014   2015    2016   2017
# Ankit   30000.0  30000  100000  80000
# Shruti  40000.0  45000  125000  90000
#         2014   2015   2016   2017
# Madhu  100.5  12000  20000  50000
# Kusum  150.8  18000  50000  60000

# %%
dict2= {
    "2018":[16000,11000,50000,34000,90000]
}
df1 = pd.DataFrame(dict2,indexes)
df1
# Out:
#           2018
# Madhu    16000
# Kusum    11000
# Kinshuk  50000
# Ankit    34000
# Shruti   90000

# %%
df1.isnull()
# Out:
#           2018
# Madhu    False
# Kusum    False
# Kinshuk  False
# Ankit    False
# Shruti   False

# %%
# 11 ) Add  df and df1
combined_df = pd.concat([df, df1], axis=1)
display(combined_df)
# Out:
#             2014   2015    2016   2017   2018
# Madhu      100.5  12000   20000  50000  16000
# Kusum      150.8  18000   50000  60000  11000
# Kinshuk    200.9  22000   70000  70000  50000
# Ankit    30000.0  30000  100000  80000  34000
# Shruti   40000.0  45000  125000  90000  90000

# %%
#trnaposing
df.transpose()
# Out:
#         Madhu    Kusum  Kinshuk     Ankit    Shruti
# 2014    100.5    150.8    200.9   30000.0   40000.0
# 2015  12000.0  18000.0  22000.0   30000.0   45000.0
# 2016  20000.0  50000.0  70000.0  100000.0  125000.0
# 2017  50000.0  60000.0  70000.0   80000.0   90000.0

# %%
print(df["2017"])
# Out:
# Madhu      50000
# Kusum      60000
# Kinshuk    70000
# Ankit      80000
# Shruti     90000
# Name: 2017, dtype: int64

# %%
# Select rows 'Madhu' and 'Ankit' and columns '2017' and '2018'
print(combined_df.loc[["Madhu", "Ankit"], ["2017", "2018"]])
# Out:
#         2017   2018
# Madhu  50000  16000
# Ankit  80000  34000

# %%
# Select the value at the intersection of row 'Shruti' and column '2016'
print(combined_df.loc["Shruti", "2016"])
df.columns
# Out:
# 125000
# Index(['2014', '2015', '2016', '2017'], dtype='object')

# %%
# df.columns
combined_df.loc["Sumit"]=[196.2,37800,52000,7838,89008]
combined_df
# Out:
#             2014     2015      2016     2017     2018
# Madhu      100.5  12000.0   20000.0  50000.0  16000.0
# Kusum      150.8  18000.0   50000.0  60000.0  11000.0
# Kinshuk    200.9  22000.0   70000.0  70000.0  50000.0
# Ankit    30000.0  30000.0  100000.0  80000.0  34000.0
# Shruti   40000.0  45000.0  125000.0  90000.0  90000.0
# Sumit      196.2  37800.0   52000.0   7838.0  89008.0

# %%
# Delete the data for sales man Kinshuk from the DataFrame
combined_df.drop("Kinshuk", inplace=True)
print(combined_df)
# Out:
#            2014     2015      2016     2017     2018
# Madhu     100.5  12000.0   20000.0  50000.0  16000.0
# Kusum     150.8  18000.0   50000.0  60000.0  11000.0
# Ankit   30000.0  30000.0  100000.0  80000.0  34000.0
# Shruti  40000.0  45000.0  125000.0  90000.0  90000.0
# Sumit     196.2  37800.0   52000.0   7838.0  89008.0

# %%
# Rename the Ankit to Vivaan and Madhu to Shailesh
combined_df.rename(index={'Ankit': 'Vivaan', 'Madhu': 'Shailesh'}, inplace=True)
display(combined_df)
# Out:
#              2014     2015      2016     2017     2018
# Shailesh    100.5  12000.0   20000.0  50000.0  16000.0
# Kusum       150.8  18000.0   50000.0  60000.0  11000.0
# Vivaan    30000.0  30000.0  100000.0  80000.0  34000.0
# Shruti    40000.0  45000.0  125000.0  90000.0  90000.0
# Sumit       196.2  37800.0   52000.0   7838.0  89008.0

# %%
# Rename the salesperson Madhu to Shailesh
combined_df.rename(index={'Madhu': 'Shailesh'}, inplace=True)
# Set the value for Shailesh in the 2018 column to 100000
combined_df.loc["Shailesh", "2018"] = 100000
# Access and print the updated value for Shailesh in the 2018 column
print(combined_df.loc["Shailesh", "2018"])
# Out:
# 100000.0

# %%
dict3 ={
    "Item" :["TV","TV","TV","AC"],
    "Company" :["lg","videocon","lg","sony"],
    "rupees":[12000,10000,15000,14000],
    "usd":[700,650,800,750]
}
df = pd.DataFrame(dict3,index=None)
df
# Out:
#   Item   Company  rupees  usd
# 0   TV        lg   12000  700
# 1   TV  videocon   10000  650
# 2   TV        lg   15000  800
# 3   AC      sony   14000  750

# %%
df.loc[4]=["phone","vivo",18000,8000]
df
# Out:
#     Item   Company  rupees   usd
# 0     TV        lg   12000   700
# 1     TV  videocon   10000   650
# 2     TV        lg   15000   800
# 3     AC      sony   14000   750
# 4  phone      vivo   18000  8000

# %%
lg_tvs = df[df["Company"] == "lg"].max()
print(lg_tvs)
# Out:
# Item          TV
# Company       lg
# rupees     15000
# usd          800
# dtype: object

# %%
total_sum = df["rupees"].sum()
print("Sum of all products:", total_sum)
# Out:
# Sum of all products: 69000

# %%
median = df["usd"].median()
print(median)
# Out:
# 750.0

# %%
dict4 ={
    "name":["Aparna","Pankaj","Ram","Ramesh","Naveen","Krishnav","Bhawna"],
    "degree":["mba","bca","m.tech","mba",None,"bca","mba"],
    "score":[90.0,None,80.0,98.0,97.0,78.0,89.0]
}
df3 =pd.DataFrame(dict4)
df3
# Out:
#        name  degree  score
# 0    Aparna     mba   90.0
# 1    Pankaj     bca    NaN
# 2       Ram  m.tech   80.0
# 3    Ramesh     mba   98.0
# 4    Naveen    None   97.0
# 5  Krishnav     bca   78.0
# 6    Bhawna     mba   89.0

# %%
max_score = df3.groupby(by = "degree")["score"].max()
print(max_score)
# Out:
# degree
# bca       78.0
# m.tech    80.0
# mba       98.0
# Name: score, dtype: float64

# %%
df3["score"] = df3["score"].fillna(76)

# %%
df3
# Out:
#        name  degree  score
# 0    Aparna     mba   90.0
# 1    Pankaj     bca   76.0
# 2       Ram  m.tech   80.0
# 3    Ramesh     mba   98.0
# 4    Naveen    None   97.0
# 5  Krishnav     bca   78.0
# 6    Bhawna     mba   89.0

# %%
df3 = df3.set_index("name")
df3
# Out:
#           degree  score
# name
# Aparna       mba   90.0
# Pankaj       bca   76.0
# Ram       m.tech   80.0
# Ramesh       mba   98.0
# Naveen      None   97.0
# Krishnav     bca   78.0
# Bhawna       mba   89.0

# %%
df3.columns
# Out:
# Index(['degree', 'score'], dtype='object')
